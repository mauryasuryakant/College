# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris

array1 =np.array([1,2,3,4,5])
print("Array 1:",array1)

array2 =np.array([[1,2,3],[4,5,6]])
print("Array2:\n",array2)
# Out:
# Array 1: [1 2 3 4 5]
# Array2:
#  [[1 2 3]
#  [4 5 6]]

# %%
df = pd.read_csv("data/data.csv")
print(df)
# Out:
#      Name  Age   City Passed Gender
# 0   Ayush   18  Surat    Yes   Male
# 1     Joy   13  Surat     No   Male
# 2    Prem   17  Surat    Yes   Male
# 3   Abhay   17  Surat    Yes   Male
# 4  Piyush   21  Surat    Yes   Male
# 5    Zaid   28  Surat    Yes   Male

# %%
zeros =np.zeros((2,3))
print("Zeros:/n,zeros")
identify =np.eye(3)
# Out:
# Zeros:/n,zeros

# %%
print("Zeros:/n",zeros)
print("ones:\n",np.ones)
# Out:
# Zeros:/n [[0. 0. 0.]
#  [0. 0. 0.]]
# ones:
#  <function ones at 0x000001BDC44FAC00>

# %%
x =np.linspace(0,10,100)
y =np.sin(x)

plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.title('sine wave')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('sine wave')
plt.show()

# %%
import pandas as pd
from IPython.display import display

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"


print("Dataframe loaded from CSV (first 5 rows)")
display(df.head())
# Out:
# Dataframe loaded from CSV (first 5 rows)
#      Name  Age   City Passed Gender
# 0   Ayush   18  Surat    Yes   Male
# 1     Joy   13  Surat     No   Male
# 2    Prem   17  Surat    Yes   Male
# 3   Abhay   17  Surat    Yes   Male
# 4  Piyush   21  Surat    Yes   Male

# %%
import pandas as pd
data = {'Column1' :[1,2,3],
        'Column2':['A','B','C']}

df = pd.DataFrame(data)

df.to_excel("out.xls", index= False)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File ~\Desktop\College\venv\Lib\site-packages\pandas\io\excel\_base.py:1171, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1170 try:
# -> 1171     engine = config.get_option(f"io.excel.{ext}.writer")
#    1172     if engine == "auto":
#
# File ~\Desktop\College\venv\Lib\site-packages\pandas\_config\config.py:187, in get_option(pat)
#     144 """
#     145 Retrieve the value of the specified option.
#     146
#    (...)    185 4
#     186 """
# --> 187 key = _get_single_key(pat)
#     189 # walk the nested dict
#
# File ~\Desktop\College\venv\Lib\site-packages\pandas\_config\config.py:131, in _get_single_key(pat)
#     130     _warn_if_deprecated(pat)
# --> 131     raise OptionError(f"No such keys(s): {pat!r}")
#     132 if len(keys) > 1:
#
# OptionError: No such keys(s): 'io.excel.xls.writer'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 7
#       2 data = {'Column1' :[1,2,3],
#       3         'Column2':['A','B','C']}
#       5 df = pd.DataFrame(data)
# ----> 7 df.to_excel("out.xls", index= False)
#
# File ~\Desktop\College\venv\Lib\site-packages\pandas\core\generic.py:2312, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs, autofilter)
#    2298 from pandas.io.formats.excel import ExcelFormatter
#    2300 formatter = ExcelFormatter(
#    2301     df,
#    2302     na_rep=na_rep,
#    (...)   2310     autofilter=autofilter,
#    2311 )
# -> 2312 formatter.write(
#    2313     excel_writer,
#    2314     sheet_name=sheet_name,
#    2315     startrow=startrow,
#    2316     startcol=startcol,
#    2317     freeze_panes=freeze_panes,
#    2318     engine=engine,
#    2319     storage_options=storage_options,
#    2320     engine_kwargs=engine_kwargs,
#    2321 )
#
# File ~\Desktop\College\venv\Lib\site-packages\pandas\io\formats\excel.py:1003, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#    1001     need_save = False
#    1002 else:
# -> 1003     writer = ExcelWriter(
#    1004         writer,
#    1005         engine=engine,
#    1006         storage_options=storage_options,
#    1007         engine_kwargs=engine_kwargs,
#    1008     )
#    1009     need_save = True
#    1011 try:
#
# File ~\Desktop\College\venv\Lib\site-packages\pandas\io\excel\_base.py:1175, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1173             engine = get_default_engine(ext, mode="writer")
#    1174     except KeyError as err:
# -> 1175         raise ValueError(f"No engine for filetype: '{ext}'") from err
#    1177 # for mypy
#    1178 assert engine is not None
#
# ValueError: No engine for filetype: 'xls'

# %%
# Load dataset
iris = load_iris()
X = iris.data
Y = iris.target

# Split dataset
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# Feature scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train model
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, Y_train)

# Predict
Y_pred = clf.predict(X_test)

# Evaluate
accuracy = accuracy_score(Y_test, Y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')

# %%
def find_s(training_data, attributes):
    num_attributes = len(attributes)

    hypothesis = ['0'] * num_attributes

    for instance in training_data:
        if instance[-1] == "Yes":
            for i in range(num_attributes):
                if hypothesis[i] == '0':
                    hypothesis[i] = instance[i]
                elif hypothesis[i] != instance[i]:
                    hypothesis[i] = '?'

    # Build final readable hypothesis
    final_hypothesis = []
    for i in range(num_attributes):
        if hypothesis[i] != '?':
            final_hypothesis.append(f"{attributes[i]} = {hypothesis[i]}")

    return final_hypothesis


# Attribute names (not values)
attributes = ['Sky', 'AirTemp', 'Humidity', 'Wind', 'Water', 'Forecast']

training_data = [
    ('Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'Yes'),
    ('Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'Yes'),
    ('Rainy', 'Cold', 'High', 'Strong', 'Warm', 'Change', 'No'),
    ('Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change', 'Yes')
]

hypothesis = find_s(training_data, attributes)
print("Final Hypothesis is :", hypothesis)
